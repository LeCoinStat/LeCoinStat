# %% [markdown]
# # 🚀  Roadmap complète pour devenir Data Scientist
#
#
# Créé par : Natacha Njongwa Yepnga Visitez la chaîne Youtube [LeCoinStat](https://www.youtube.com/c/LeCoinStat)
# Inspiré par la vidéo: [https://www.youtube.com/watch?v=QnGotm29cZE&t=76s](https://www.youtube.com/watch?v=QnGotm29cZE&t=76s)

# %% [markdown]
# # 🌟  Introduction
#
# ## 🎯 Objectif
#
# L'objectif de ce notebook est de vous offrir une vue d'ensemble des compétences nécessaires pour mener à bien des projets de data science de façon exhaustive. L'internet regorge de ressources, mais il peut être difficile de déterminer lesquelles sont les plus utiles. C'est pourquoi, dans ce notebook, j'ai également rassemblé mes ressources conseillées pour vous accompagner dans l'apprentissage de ces compétences.

# %% [markdown]
# ## 📘 Comment exploiter ce notebook?
#
# Vous êtes libre de choisir le domaine à explorer en premier lieu. Veuillez noter que la séquence d'apprentissage des compétences n'est pas strictement définie (!), à condition que vous ayez une base solide en programmation et en mathématiques/statistiques. **N'oubliez pas d'allier théorie et pratique !**

# %% [markdown]
# # 📊 Statistiques Descriptives

# %% [markdown]
# ![https://www.scribbr.de/wp-content/uploads/2023/01/Descriptive-statistics.webp](https://www.scribbr.de/wp-content/uploads/2023/01/Descriptive-statistics.webp)

# %% [markdown]
# L'objectif de cette partie est de:
#
# - Définir et utiliser le vocabulaire statistique (population, observation, échantillon, caractère)
# - Sur une problématique donnée être capable de choisir les outils d'exploration adaptée pour la base de données
# - Faire des graphique pertinent
# - Savoir interpréter les résultats

# %% [markdown]
# ## Statistique univariée
#   - Types de variables (qualitatives, quantitatives, ordinales, etc.)
#   - Mesures de tendance centrale (moyenne, médiane, mode)
#   - Mesures de dispersion (écart-type, variance)
#   - Fréquences et proportions
#   - Graphiques et visualisation de données (histogrammes, diagrammes en barres, diagrammes circulaires, boxplot etc.)

# %% [markdown]
# **Projet 1:**  Faire un projet de statistique descriptive univariée avec Excel

# %% [markdown]
# ## Statistique bivariée :
# - **Graphiques pour la visualisation des relations entre variables :**
#     - *Variables qualitatives-qualitatives* : diagramme en barres, diagramme en secteurs.
#     - *Variables qualitatives-quantitatives* : boîte à moustaches, diagramme en violon, diagramme en barres.
#     - *Variables quantitatives-quantitatives* : nuage de points, diagramme de densité.
#
# - **Liaison entre deux variables quantitatives** : coefficient de corrélation linéaire.
#
# - **Liaison entre deux variables qualitatives** : tableau de contingence, statistique du Khi-deux (χ²).
#
# - **Liaison entre une variable quantitative et une variable qualitative** : rapport de corrélation, analyse de variance à un facteur.

# %% [markdown]
# **Projet 2:** Faire un projet qui permet d'analyser des variables deux à deux avec Excel

# %% [markdown]
# ## Ressources et Cours
#
#
# 1. **Khan Academy** :
#     - [Statistiques et probabilités](https://fr.khanacademy.org/math/statistics-probability)
#
# 2. **Coursera** :
#     - [Data Science Math Skills par Duke University](https://www.coursera.org/learn/datasciencemathskills)
#     - [Basic Statistics par University of Amsterdam](https://www.coursera.org/learn/basic-statistics)
#
# 3. **edX** :
#     - [Introduction to Probability and Data par Duke University](https://www.edx.org/course/introduction-to-probability-and-data)
#
# 4. **MIT OpenCourseWare** :
#     - [Introduction to Probability and Statistics](https://ocw.mit.edu/courses/mathematics/18-05-introduction-to-probability-and-statistics-spring-2014/)
#
# 5. **YouTube** :
#     - [LeCoinStat](https://www.youtube.com/c/LeCoinStat)
#     - [Brandon Foltz](https://www.youtube.com/user/BCFoltz)
#     - [jbstatistics](https://www.youtube.com/user/jbstatistics)
#     - [StatQuest avec Josh Starmer](https://www.youtube.com/user/joshstarmer)
#     - [https://www.youtube.com/@kozyrkov](https://www.youtube.com/@kozyrkov)

# %% [markdown]
# # 💻 Programmation
# Pour manipuler efficacement les données et développer des applications liées à la data science, vous devrez maîtriser certains langages de programmation. Les plus couramment utilisés sont :
#
# - Python
# - SQL
# - R
# - SAS (particulièrement utile dans le secteur financier)
# - JavaScript/C++/Java (pour le développement d'applications à grande échelle)
#
# Ci-dessous, un aperçu des langages de programmation les plus utilisés dans le domaine de la science des données selon les enquêtes Kaggle de 2018 à 2021. Python, SQL et R sont indéniablement en tête.
# ![graphique](kaggle_survey.png)
#
# Source : [https://www.kaggle.com/code/lynnxy/a-deep-dive-into-the-kaggle-survey-from-2017-2021#1.-Introduction](https://www.kaggle.com/code/lynnxy/a-deep-dive-into-the-kaggle-survey-from-2017-2021#1.-Introduction)
#
#
#
# Même si les outils spécifiques et l'infrastructure de data science peuvent différer d'une entreprise à l'autre, une base solide vous équipera pour apprendre et maîtriser rapidement tout nouvel outil ou compétence qui pourrait se présenter sur votre chemin.

# %% [markdown]
# # 📚 Algorithmique et progammation avec Python
#
# La compréhension des concepts fondamentaux de l'algorithmique et de la complexité est cruciale pour tout data scientist. Cela permet non seulement de développer des compétences en programmation efficace, mais également de mieux comprendre le fonctionnement interne des algorithmes de machine learning, tout en offrant des outils pour résoudre de manière plus systématique et optimisée des problèmes complexes.
#
# **L'objectif ici est d'acquerir:**
# - Les éléments de bases de tout langage impératifs (variables, boucles, test, fonction, classes).
# - Notions d'algorithme : récurrence, coût d'un algorithme, programmation dynamique, dichotomie.
#
#
#
#
#
# ## 📕 Bases de l'Algorithmique
# - Définition et caractéristiques d'un algorithme
# - Conception d'algorithmes: pseudo-code et diagrammes de flux
# - Structures de contrôle: séquence, sélection, répétition
# - Recherche et tri: recherche linéaire, recherche binaire, tri par sélection, tri à bulles, tri par insertion, tri rapide, tri fusion
# - Recursivité: définition, exemples classiques (factorielle, Fibonacci), avantages et inconvénients
# - Procédures et fonctions
#
# ## 📗 Structures de Données
# - Tableaux et listes: utilisation, avantages et inconvénients
# - Listes chaînées: liste simple, liste doublement chaînée
# - Arbres: arbres binaires, arbres de recherche binaire, arbres AVL, arbres B
# - Graphes: définition, représentation
#
# ## 📕 Langage python
# - Manipulation des données
# - Boucles, tests, fonctions
# - Classes et programmation objet
# - Exceptions
# - Modules
# - Interface graphique
#
# ## 📗 Algorithmes (programme de l'ENSAE)
#
#
# - Algorithmes de tri
# - Files d’attente, simulation informatique
# - Plus court chemin dans un graphe
# - Plus court chemin reliant tous les noeuds d’un graphe, cartes de Kohonen
# - Distance d’édition, distance entre deux séquences
# - Optimisation numérique, algorithmes BFGS, DFP Classification à l'aide des k plus proches voisins (k-PPV), -optimisation de la recherche du plus proche voisin
# - Modèles de Markov cachés et algorithme Expectation-Maximisation (EM)
#
#
# ## 📚 Ressources pour l'Apprentissage
#
#
# - [Khan Academy: Algorithmes](https://www.khanacademy.org/computing/computer-science/algorithms)
# - [Geeks for Geeks: Structures de données](https://www.geeksforgeeks.org/data-structures/)
# - [Coursera: Algorithmes spécialisés](https://www.coursera.org/specializations/algorithms)
# - [MIT OpenCourseWare: Introduction à l'algorithmique](https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-006-introduction-to-algorithms-fall-2011/index.htm)
# - [EdX: Algorithmes et structures de données](https://www.edx.org/micromasters/ucsandiegox-algorithms-and-data-structures)

# %% [markdown]
# Pour vous entrainer: [http://www.xavierdupre.fr/app/ensae_teaching_cs/helpsphinx/td_1a.html](http://www.xavierdupre.fr/app/ensae_teaching_cs/helpsphinx/td_1a.html)

# %% [markdown]
# ![https://www.datasciencecentral.com/wp-content/uploads/2021/10/3840441960-1.png](https://www.datasciencecentral.com/wp-content/uploads/2021/10/3840441960-1.png)

# %% [markdown]
# ##  Python
# Qu'est-ce que c'est ?
# Python est un langage de programmation généraliste et de haut niveau largement utilisé. Il a été initialement conçu par Guido van Rossum en 1991 et développé par la Python Software Foundation. Il a été principalement développé pour mettre l'accent sur la lisibilité du code, et sa syntaxe permet aux programmeurs d'exprimer des concepts en moins de lignes de code.
#
# # 📚 Python pour la Data Science
#
# ## 📕 Les bases de Python
#
# ### Environnements de développement intégrés (IDE) populaires pour Python :
#
# - [Pycharm](https://www.jetbrains.com/pycharm/)
# - [VSCode](https://code.visualstudio.com/)
# - [Jupyterlab/Jupyter Notebook](https://jupyter.org/) pour la programmation interactive
# - [Google Colab](https://colab.research.google.com/) pour le développement en ligne
#
# ### Bibliothèques importantes :
# - pandas
# - numpy
# - matplotlib
# - sklearn (pour l'apprentissage automatique)
# - requests (pour travailler avec des API)
#
# ### Bien débuter avec Python :
# - Types de données
# - Variables
# - Conversion de types
# - Opérateurs (affectation, logiques, arithmétiques, etc.)
# - Instructions conditionnelles (if, else, elif)
# - Collections : Liste, Tuple, Ensembles et Dictionnaire
# - Compréhension de liste
# - Boucles en Python (for, while et boucles imbriquées)
# - Manipulation de chaînes
# - Fonctions définies par l'utilisateur
# - Fonction lambda
# - Installation et importation de modules
#
# ## 📗 Python intermédiaire
# - Environnement virtuel
# - Enumerate
# - Zip et unzip
# - Map, Filter et Reduce
# - *args et **kwargs
# - Erreurs et gestion des exceptions
# - Gestionnaires de contexte
# - Création de modules Python
#
# ## 📘 Programmation orientée objet (POO) en Python
# - Bases de la programmation orientée objet
# - Création de classe et d'objet
# - Constructeurs (paramétrés et non paramétrés)
# - Héritage en Python
# - Méthodes et attributs de classe intégrés
# - Héritage multi-niveaux et multiple
# - Surcharge de méthode et abstraction de données
# - Encapsulation
# - Polymorphisme
#
#
# **Ressources, cours et certificats Python**
# - Spécialisation Python for Everybody (Coursera)
# - Data Science appliquée avec Python (Coursera)
# - Python Tips (gratuit en ligne) - pour référence
# - 📚 Python for Data Analysis
# - 📚 Automate the Boring Stuff with Python
# - 📚 Livre Python interactif (How to Think Like a Computer Scientist, Runestone Academy)

# %% [markdown]
# Python pour la data science lien utile [https://pythonds.linogaliana.fr/](https://pythonds.linogaliana.fr/)
#
# Pour bien démarrer en python vous pouvez suivre les daily live coding sur LeCoinStat [https://www.youtube.com/watch?v=jqZ3ATcm3yE&list=PLyh35eYRez8eiEt_0oVVqLDfnpxON2pZ-&index=2](https://www.youtube.com/watch?v=jqZ3ATcm3yE&list=PLyh35eYRez8eiEt_0oVVqLDfnpxON2pZ-&index=2)

# %% [markdown]
# **Projet 3:** Faire un projet de statistique descriptive univariée et bivariée en Python

# %% [markdown]
# ## R
#
# ![https://devtechnosys.com/insights/wp-content/uploads/2023/02/What-Is-R-Programming.png](https://devtechnosys.com/insights/wp-content/uploads/2023/02/What-Is-R-Programming.png)
#
# R est un langage de programmation axé sur le calcul statistique et la création de visualisations graphiques. Élaboré par Ross Ihaka et Robert Gentleman à l'Université d'Auckland en 1991, R est une extension du langage S. Son nom, reflétant les initiales de ses inventeurs, évoque aussi son héritage du langage S. R est fréquemment utilisé dans les domaines du data mining, de la bioinformatique et des statistiques pour analyser des données et développer des logiciels statistiques.
#
# ### Découvrir les Bases de R
#
# **Environnements de Développement Intégrés (IDE) :**
# - **RStudio** : Une plateforme complète pour la programmation en R, favorisant la productivité et la collaboration.
#
# **Bibliothèques Fondamentales :**
# - **dplyr** et **tidyr** : Des outils performants pour la manipulation et le nettoyage des données.
# - **ggplot2** : Un système sophistiqué pour créer des visualisations de données expressives.
# - **shiny** : Pour construire des applications web interactives directement en R.
# - **plotly** : Permet de créer des graphiques interactifs.
# - **caret** : Une boîte à outils complète pour le machine learning en R.
# - **lubridate** : Simplifie la gestion des dates et heures.
# - **stringr** : Fonctions pratiques pour la manipulation de chaînes de caractères.
# - Rmarkdown et Quarto pour une documentation dynamique
#
# **Compétences de Base :**
# - Compréhension des différents types de données en R.
# - Manipulation de structures de données telles que vecteurs, matrices, et dataframes.
# - Maîtrise des instructions conditionnelles et des boucles.
# - Utilisation des fonctions `apply` pour des opérations efficaces sur les données.
# - Introduction aux statistiques descriptives avec R.
# - Gestion de projets dans RStudio.
# - Installation et utilisation de bibliothèques pour élargir les capacités de R.
#
# ### Approfondir vos Connaissances en R
#
# **Sujets Avancés :**
# - Stratégies avancées pour la gestion des erreurs et le débogage.
# - Compréhension de la portée des variables et des environnements en R.
# - Création et maintenance de packages R.
#
# Ressources, cours et certificats R
# - Spécialisation Data Analysis with R (Coursera)
# - 📚 R for Data Science (Hadley Wickham & Garrett Grolemund)
# - 📚 Advanced R by Hadley Wickham

# %% [markdown]
# **Projet 4:** Faire le projet de statistique descriptive univariée et bivariée en R

# %% [markdown]
# ## Pour bien écrire ces codes:
#
# Avant de commencer à programmer il faut bien penser au style que vous allez adopter.
#
# ### R
# - [**Guide de style R de Google**](https://google.github.io/styleguide/Rguide.html) : Ce guide offre des suggestions pour l'écriture de code R, notamment sur la syntaxe, la nomination, les commentaires et l'organisation.
# - [**Tidyverse style guide**](https://style.tidyverse.org/) : Ce guide est spécifiquement destiné à l'écriture de code R dans l'écosystème Tidyverse, un ensemble de packages R pour le nettoyage, la manipulation et la visualisation de données.
#
# ### Python
# - [**PEP 8**](https://pep8.org/) : C'est le guide de style pour le code source Python. Il aborde des sujets comme l'indentation, les conventions de nommage, les espaces blancs, etc.
# - [**PEP 484**](https://www.python.org/dev/peps/pep-0484/) : Cette proposition d'amélioration de Python introduit la notation pour les annotations de type, ce qui peut aider à rendre votre code Python plus clair et plus facile à maintenir.
#
# Adopter un style de codage cohérent facilite également la collaboration avec d'autres, car cela rend votre code plus prévisible et compréhensible pour ceux qui pourraient avoir à le lire ou à y contribuer.
#
# ### 🛠️ Outils pour aider à respecter les bonnes pratiques de codage
#
# #### Python
#
# - **pytest** : Un cadre de test pour Python. Apprendre à l'utiliser vous permettra d'écrire des tests unitaires pour votre code, ce qui est essentiel pour vérifier que votre code fonctionne comme prévu. Vous pouvez en savoir plus sur pytest [ici](https://docs.pytest.org/en/latest/).
#
# - **pylint** : Un linter de code pour Python qui vérifie que votre code respecte la convention PEP 8. C'est un outil précieux pour s'assurer que votre code suit les bonnes pratiques de codage. Plus d'informations sur pylint peuvent être trouvées [ici](https://www.pylint.org/).
#
# Adopter un style de codage cohérent facilite également la collaboration avec d'autres, car cela rend votre code plus prévisible et compréhensible pour ceux qui pourraient avoir à le lire ou à y contribuer.
#
# #### R
#
# - **lintr** : Un outil de contrôle de syntaxe pour R. Il vérifie que votre code est bien formaté et suit les conventions de codage. Plus d'informations sur lintr peuvent être trouvées [ici](https://github.com/jimhester/lintr).
# - **testthat** : Un framework de tests unitaires pour R. Il vous aide à écrire des tests pour votre code afin de vous assurer que tout fonctionne comme prévu. Vous pouvez en savoir plus sur testthat [ici](https://testthat.r-lib.org/).
# - **styler** : Un package qui peut reformater votre code R pour le rendre plus propre et conforme aux conventions de style. Plus d'informations sur styler peuvent être trouvées [ici](https://styler.r-lib.org/).
#
#
#
# Chaque entreprise peut avoir des outils et une infrastructure de data science différents. Cependant, si vous avez des bases solides, il ne fait aucun doute que vous pouvez facilement apprendre de nouvelles compétences et de nouveaux outils en chemin.

# %% [markdown]
# # 🔢 Mathématiques et probabilités
#
# ![https://interviewquestions.guru/wp-content/uploads/2024/01/Mind-Map-Mathematics-for-Data-Science.webp](https://interviewquestions.guru/wp-content/uploads/2024/01/Mind-Map-Mathematics-for-Data-Science.webp)
#
# Les mathématiques et les probabilités avancées sont primordiales pour l'apprentissage automatique et les analyses statistiques avancées. Ne vous inquiétez pas si vous ne maîtrisez pas tout, **l'essentiel est de progresser à votre rythme :)**

# %% [markdown]
# ## 📈 Algèbre
#
# L'algèbre linéaire et bilinéaire est fondamentale dans le domaine de la data sciencee cours présente les notions essentielles d'algèbre, en mettant l'accent sur la réduction des matrices, en particulier dans le cas symétrique réel, et sur l'importance de la projection orthogonale et de ses applications.
#
# En apprenant l'algèbre, vous devez être en mesure de:
# - Appliquer les techniques du calcul matriciel : changement de base, inversion, détermination du déterminant, réduction de matrices, résolution de systèmes linéaires.
# - Démontrer et utiliser les propriétés caractéristiques des espaces euclidiens.
# - Énoncer et appliquer les propriétés des projections orthogonales.
#
# #### Propriétés fondamentales des matrices et des vecteurs
#
# - Multiplication scalaire, transformation linéaire, transposition, conjugaison.
# - Rang, déterminant.
#
# #### Manipulations de matrices
#
# - Produits intérieurs et extérieurs, règles de multiplication.
# - Inversion de matrices.
# - Types de matrices : carrée, identité, triangulaire, matrices creuses et denses, vecteurs unitaires, matrices symétriques.
#
# #### Décomposition et factorisation des matrices
#
# - Factorisation LU, décomposition en valeurs singulières.
# - Élimination de Gauss, méthode Gauss-Jordan.
#
# #### Résolution des systèmes d'équations linéaires
#
# - Techniques pour résoudre des équations du type Ax = b.
#
# #### Espaces vectoriels
#
# - Concepts de base : espace vectoriel, bases, ensembles engendrés.
# - Orthogonalité, orthonormalité, moindres carrés linéaires.
# - Noyau, image, rang d'une application linéaire.
# - Sous-espaces vectoriels, projecteurs associés.
#
# #### Théorie spectrale
#
# - Valeurs propres, vecteurs propres.
# - Diagonalisation, décomposition en valeurs singulières.
#
# #### Applications supplémentaires en Algèbre
#
# - Opérations élémentaires sur les lignes et les colonnes.
# - Réduction des endomorphismes : diagonalisation, théorème spectral.
# - Formes quadratiques : définitions, orthogonalité, matrice associée, réduction de Gauss.
# - Espaces Euclidiens : définitions, orthogonalisation de Schmidt, matrices orthogonales, projection orthogonale, matrices symétriques réelles.

# %% [markdown]
# ## 📉 Analyse
# - Limites
# - Continuité de fonctions
# - Dérivée d'une fonction
# - Règles de dérivation
# - Intégrales
# - Techniques d'intégration
# - Dérivées partielles
# - Règle de la chaîne
# - Maxima et minima
# - Séries et séquences
# - Équations différentielles
# - Fonctions multivariables
# - Intégrales multiples
#
# ## ⚙️ Optimisation
# - Fonctions convexes et concaves
# - Opérations préservant la convexité
# - Conditions de premier et de second ordre pour l'optimalité
# - Méthodes d'optimisation
#   - Gradient descente
#   - Descente de gradient stochastique
#   - Méthode de Newton
#   - Méthode du lagrangien
#   - Optimisation par recherche linéaire et par région de confiance
# - Contraintes d'optimisation et problèmes d'optimisation sous contraintes
# - Optimisation convexe et non-convexe
# - Optimisation combinatoire
# - Programmation linéaire, quadratique et dynamique
#
# ## 🎲 Probabilité
# - Probabilité conditionnelle et indépendance
# - Théorème de Bayes
# - Distributions de probabilité communes
# - Variables aléatoires et espérance mathématique
# - Variance et moments supérieurs
# - Lois des grands nombres
# - Théorème central limite
# - Distributions discrètes (Binomiale, Poisson, Géométrique, etc.)
# - Distributions continues (Uniforme, Normale, Exponentielle, etc.)
# - Distributions multivariées
# - Fonctions génératrices de moments
# - Transformée de Laplace et de Fourier
# - Processus stochastiques (si vous souhaitez travailler en finance)
# - Chaînes de Markov (si vous souhaitez travailler en finance)

# %% [markdown]
# ## Ressources et cours :
# 1. **Khan Academy** :
#     - [Mathématiques](https://fr.khanacademy.org/math)
#     - [Statistiques et probabilités](https://fr.khanacademy.org/math/statistics-probability)
#
# 2. **Coursera** :
#     - [Mathematics for Machine Learning par Imperial College London](https://www.coursera.org/specializations/mathematics-machine-learning)
#     - [Probabilistic Graphical Models par Stanford University](https://www.coursera.org/specializations/probabilistic-graphical-models)
#
# 3. **edX** :
#     - [Probability - The Science of Uncertainty and Data par MITx](https://www.edx.org/course/probability-the-science-of-uncertainty-and-data)
#
# 4. **MIT OpenCourseWare** :
#     - [Mathématiques pour la science des données](https://ocw.mit.edu/courses/mathematics/18-650-statistics-for-applications-fall-2016/)
#     - [Probabilités](https://ocw.mit.edu/courses/mathematics/18-05-introduction-to-probability-and-statistics-spring-2014/)
#
#
#
# Prenez le temps d'étudier ces sujets et de consolider votre compréhension des mathématiques et de la probabilité pour exceller dans le domaine de la science des données.

# %% [markdown]
# ## SQL (Structured Query Language)
#
#
#
# SQL est un langage de programmation conçu pour gérer les données stockées dans des bases de données relationnelles. Le langage SQL est largement utilisé aujourd'hui dans les frameworks web et les applications de base de données. Il permet de maintenir l'exactitude et la sécurité des données, et contribue à maintenir l'intégrité des bases de données, quel que soit leur taille.
#
#
# # 📚 SQL pour la Data Science
#
# ## 📕 SQL Débutant
# Sujets :
# 1. Introduction au système de gestion de base de données relationnelle (RDBMS)
# 2. Conception de bases de données
#     - Diagramme entité-relation (ERD)
#     - Clé primaire
#     - Clé étrangère
#     - Normalisation de la base de données
# 3. Syntaxe SQL de base
#     - Types de données
#     - Opérateurs et expressions
#     - Créer, sélectionner, supprimer une base de données
#     - Créer, supprimer une table
#     - Requête CRUDE :
#         - Création de données (Requête INSERT)
#         - Lecture de données (Requête SELECT)
#         - Mise à jour de données (Requête UPDATE)
#         - Suppression de données (Requête DELETE)
# 4. Filtrage et Tri des données
#     - Clause WHERE
#     - Clauses AND, OR, NOT
#     - Clause LIKE
#     - Clause ORDER BY
# 5. Regroupement et Fonctions d'agrégation
#     - Clause GROUP BY
#     - Fonction DISTINCT
#     - Fonctions d'agrégation (SUM, AVG, MIN, MAX, COUNT)
# Les Jointures (Left Join, Inner Join, Right Join, Outer Join)
#
# ## 📗 SQL Intermédiaire
# Sujets :
# 1. Contraintes de base de données
# 2. Gestion des valeurs NULL
# 3. Syntaxe des alias
# 4. Opérations sur les tables
#     - Indexation
#     - Commande ALTER TABLE
#     - Tronquer une table
# 5. Manipulation avancée des données
#     - Utilisation des vues
#     - Clause HAVING
#     - Transactions SQL
#     - Jokers
#     - Fonctions de date
# 6. Techniques SQL intermédiaires
#     - Tables temporaires
#     - Clonage des tables
#     - Utilisation des séquences
#     - Gestion des doublons
#     - Prévention de l'injection SQL
#
# ## 📘 SQL Avancé
# Sujets :
# 1. Techniques avancées de requête
#     - Sous-requêtes
#     - Opérations ensemblistes (UNION, UNION ALL, INTERSECT, MINUS)
# 2. Extensions de regroupement
#     - Extensions GROUP BY (ROLLUP, CUBE et GROUPING SETS)
# 3. Fonctions de fenêtrage
#      - RANK(), DENSE_RANK(), ROW_NUMBER() etc.
#     - Utilisation de OVER(PARTITION BY ...)
# 4. Partitionnement de données
#     - PARTITION BY
# 5. Requêtes récursives
# - Utilisation de la clause WITH RECURSIVE pour des requêtes complexes
#
# 6. Manipulation avancée des vues

# %% [markdown]
# **Ressources SQL, cours et certificats**
# 1. [Codecademy - Learn SQL](https://www.codecademy.com/learn/learn-sql)
# 2. [Khan Academy - Intro to SQL](https://www.khanacademy.org/computing/computer-programming/sql)
# 3. https://www.w3schools.com/sql/default.asp
# 4. [Stanford University - Databases](https://lagunita.stanford.edu/courses/DB/SQL/SelfPaced/about)
# 5. [SQLZoo](https://sqlzoo.net/)
# 6. [Mode Analytics - SQL Tutorial: Learn SQL with MySQL Database](https://mode.com/sql-tutorial/)
# 7. [Coursera - SQL for Data Science by University of California, Davis](https://www.coursera.org/learn/sql-for-data-science)
# 8. [DataCamp - SQL Server courses](https://www.datacamp.com/courses/tech:sql_server)
# 9. [Udemy - SQL - MySQL for Data Analytics and Business Intelligence](https://www.udemy.com/course/sql-mysql-for-data-analytics-and-business-intelligence/)
#
# Pour réaliser des projets: https://8weeksqlchallenge.com/getting-started/

# %% [markdown]
# **Projet 5:** Faire un projet complet avec SQL

# %% [markdown]
# #  Visualisation des données
#
#
# La visualisation des données est la représentation des données à travers des graphiques courants, tels que des diagrammes, des graphiques, des infographies et même des animations. Ces représentations visuelles de l'information communiquent des relations de données complexes et des connaissances basées sur les données de manière facile à comprendre.
#
# La visualisation des données peut être créée à l'aide de Python/R ou de logiciels propriétaires tels que Tableau et PowerBI (qui sont des outils de tableau de bord populaires dans les entreprises).
#
# Bibliothèques populaires de visualisation des données en Python :
# - matplotlib
# - bokeh
# - plotly
# - seaborn
# - altair
#
# Bibliothèques populaires de visualisation des données en R :
# - ggplot2
# - plotly
#
# Ressources, cours et certificats de visualisation des données
# - Spécialisation Data Visualization with Tableau (Coursera)
# - Cours PowerBI (Codebasics)
# - 📚 Storytelling with Data
# - Projets de portfolio de visualisation de données
# - Création d'un tableau de bord interactif de visualisation en Python avec Panel
# - Benjamin Ejzenberg : [https://www.youtube.com/@BenjaminEjzenberg](https://www.youtube.com/@BenjaminEjzenberg)
#
# **Projet 6:** Faire un projet de dataviz avec R ou python

# %% [markdown]
# # Statistique inférentielle
#
# ![https://datatab.fr/assets/tutorial/Statistiques_descriptives_et_statistiques_inf%C3%A9rentielles.png](https://datatab.fr/assets/tutorial/Statistiques_descriptives_et_statistiques_inf%C3%A9rentielles.png)
#
# La statistique inférentielle est une branche de la statistique qui traite de l'inférence et de la prise de décision à partir d'un échantillon représentatif d'une population plus large. Elle permet de tirer des conclusions et de faire des prédictions sur la population en utilisant les principes de l'échantillonnage et de l'estimation statistique.
#
# Sujets clés :
#
# ## Echantillonage et techniques de sondages
#
# - Echantillonnage aléatoire simple
# - Echantillonnage stratifié
# - Echantillonnage en grappes
# - Méthodes de redressement
#
# ## Estimation
# L'estimation est une étape fondamentale en statistique qui vise à estimer les paramètres de la population à partir des données de l'échantillon, en utilisant des techniques d'estimation ponctuelle et d'estimation par intervalle de confiance.
#
# ### Estimation ponctuelle
#
# L'estimation ponctuelle consiste à estimer un paramètre de la population par une seule valeur, appelée estimateur ponctuel. L'estimateur ponctuel est généralement calculé à partir des statistiques descriptives de l'échantillon. Par exemple, la moyenne de l'échantillon peut être utilisée comme estimateur ponctuel de la moyenne de la population.
#
# L'estimation ponctuelle repose sur différentes méthodes, telles que la méthode des moments, la méthode des moindres carrés et la méthode du maximum de vraisemblance. Chacune de ces méthodes peut être utilisée en fonction des hypothèses et des caractéristiques de l'échantillon.
#
# ### Estimation par intervalle de confiance
#
# L'estimation par intervalle de confiance est une approche qui permet d'estimer un paramètre de la population en donnant un intervalle de valeurs possibles avec un niveau de confiance spécifié. L'intervalle de confiance fournit une estimation plus précise du paramètre en tenant compte de l'incertitude liée à l'échantillon.
#
# La construction d'un intervalle de confiance repose sur des techniques statistiques telles que la distribution de l'échantillon, la taille de l'échantillon et le niveau de confiance souhaité. Par exemple, un intervalle de confiance à 95 % signifie que si l'on répète l'expérience un grand nombre de fois, 95 % de ces intervalles contiendront le véritable paramètre de la population.
#
# L'estimation par intervalle de confiance offre une meilleure compréhension de la précision de l'estimation et permet de prendre en compte l'erreur d'échantillonnage.
#
#
#
# ## Tests statistiques
#
# ### Tests d'adéquation et de normalité
# - Test du khi-deux pour l'adhéquation : utilisé pour tester si un échantillon suit une distribution théorique spécifiée.
# - Tests de normalité : comprendre les tests de normalité tels que le test de Shapiro-Wilk, le test de Kolmogorov-Smirnov, et le test d'Anderson-Darling pour vérifier si un échantillon suit une distribution normale.
#
# ## Corrélations
# - Coefficient de corrélation de Pearson : utilisé pour mesurer la corrélation linéaire entre deux variables continues.
# - Coefficient de corrélation de Spearman : utilisé pour mesurer la corrélation monotone entre deux variables continues ou ordinales.
# - Coefficient de corrélation de Kendall : utilisé pour mesurer la corrélation entre deux variables ordinales.
#
#
# ### Tests d'indépendance
# - Test du khi-deux pour l'indépendance : utilisé pour tester l'indépendance entre deux variables catégorielles.
# - Test de Fisher : utilisé pour tester l'indépendance entre deux variables catégorielles dans un tableau de contingence.
# - Mesures d'association :
#   - Coefficient de contingence : mesure la force de la relation entre deux variables catégorielles.
#   - Coefficient V de Cramér : mesure la force de la relation entre deux variables nominales.
#   - Coefficient T de Tschuprow : mesure la force de la relation entre deux variables nominales.
#
#
# ## Tests de comparaison de moyennes (paramétrique et non paramétrique)
# - Test t de Student : utilisé pour comparer les moyennes de deux échantillons indépendants.
# - Test de Welch : utilisé pour comparer les moyennes de deux échantillons indépendants avec des variances inégales.
# - Test de Wilcoxon : utilisé pour comparer les distributions de deux échantillons appariés ou indépendants non normalement distribués.
#
#
# ## Tests de comparaison de groupes (paramétrique et non paramétrique)
# - Test d'égalité des proportions : utilisé pour comparer les proportions de deux groupes indépendants.
# - Test d'ANOVA (Analyse de variance) : utilisé pour comparer les moyennes de plusieurs groupes indépendants.
# - Test de Kruskal-Wallis : utilisé pour comparer les distributions de plusieurs groupes indépendants non normalement distribués.
#
# ## Tests d'égalité des variances
# - Test de Levene : utilisé pour tester l'égalité des variances entre deux groupes.
# - Test de Bartlett : utilisé pour tester l'égalité des variances entre plusieurs groupes.
#
#
# Ressources  :
#
# - Cours: [https://josephsalmon.eu/enseignement/ENSAE/StatAppli_tsybakov.pdf](https://josephsalmon.eu/enseignement/ENSAE/StatAppli_tsybakov.pdf)
# - Cours très mathématique [https://egrcc.github.io/docs/math/all-of-statistics.pdf](https://egrcc.github.io/docs/math/all-of-statistics.pdf)

# %% [markdown]
# **Projet 7:** Faire un projet pour consolider les connaissances sur les tests statististiques

# %% [markdown]
# # 📊 Analyses Factorielles
#
# Les analyses factorielles sont des techniques statistiques utilisées pour explorer et interpréter les relations entre un grand nombre de variables. Elles permettent de réduire la dimensionnalité des données et de découvrir des structures sous-jacentes.
#
# Sujets :
# - Analyse en Composantes Principales (ACP) : réduction de dimension, visualisation des données, interprétation des composantes principales
# - Analyse des Correspondances Multiples (ACM) : analyse de données catégorielles, visualisation des profils, analyse de l'inertie
# - Analyse Factorielle des Correspondances (AFC) : analyse de données catégorielles, mise en évidence des relations entre variables
# - Analyse Factorielle Discriminante (AFD) : classification et discrimination des individus
# - Autres techniques d'analyses factorielles : Analyse Factorielle des Données Mixtes (AFDM), Analyse Factorielle des Correspondances Simples (AFCS), etc.
#
# Outils :
# - Bibliothèques Python : scikit-learn, prince
# - Bibliothèques R : FactoMineR, factoextra, Factoshiny
#
# Ressources:
#
# -Statistique exploratoire multidimensionnelle [https://horizon.documentation.ird.fr/exl-doc/pleins_textes/divers11-10/010007837.pdf](https://horizon.documentation.ird.fr/exl-doc/pleins_textes/divers11-10/010007837.pdf)
#
# **Projet 8**: Faire un projet en utilisant une méthode d'analyse factorielle sous R Ou Python

# %% [markdown]
# ![https://miro.medium.com/v2/resize:fit:1400/format:webp/1*FUZS9K4JPqzfXDcC83BQTw.png](https://miro.medium.com/v2/resize:fit:1400/format:webp/1*FUZS9K4JPqzfXDcC83BQTw.png)

# %% [markdown]
# # 🤖 Apprentissage non supervisé
#
# L'apprentissage non supervisé est une branche de l'apprentissage automatique qui vise à découvrir des structures et des modèles dans les données sans étiquettes ou sans objectif de prédiction.
#
# Sujets :
# - Clustering : regroupement des données similaires dans des groupes homogènes (ex : K-means, clustering hiérarchique, DB Scan)
# - Réduction de dimension : extraction des caractéristiques les plus informatives (ex : Analyse en Composantes Principales, t-SNE)
#
# Outils :
# - Bibliothèques Python : scikit-learn
# - Bibliothèques R : stats
#
#
# **Projet 9**: Faire un projet d'apprentissage non suppervisé

# %% [markdown]
# # 🤖 Apprentissage supervisé

# %% [markdown]
# - **Comprendre la validation croisée** : une technique d'évaluation des performances des modèles en divisant les données en ensembles d'entraînement et de test (ex : cross_val_score)
# - **Les étapes d'un projet de modélisation** : comprendre les différentes étapes, de l'exploration des données à la construction du modèle, en passant par la sélection des fonctionnalités et l'optimisation des hyperparamètres
# - **Comment traiter les valeurs aberrantes** : identifier et gérer les valeurs aberrantes dans les données pour éviter qu'elles n'affectent négativement les performances du modèle (ex : boxplot, z-score)
# - **Comment traiter les valeurs manquantes** : gérer les valeurs manquantes dans les données en utilisant des techniques telles que l'imputation ou la suppression des lignes ou des colonnes correspondantes (ex : fillna, dropna)
# - **Comment évaluer les performances d'un modèle **: utiliser des métriques d'évaluation telles que l'exactitude, la précision, le rappel, le score F1 et la courbe ROC pour mesurer la performance d'un modèle (ex : accuracy_score, precision_score, recall_score, f1_score, roc_auc_score)
# - **Comment réaliser l'ingénierie des caractéristiques (feature engineering)** : transformer les variables existantes ou créer de nouvelles variables pour améliorer les performances du modèle (ex : création de variables indicatrices, transformation logarithmique)
# - **Comment sélectionner les meilleures variables** : utiliser des méthodes telles que l'analyse univariée, la corrélation, l'importance des variables, et les techniques de sélection automatique des variables pour choisir les caractéristiques les plus pertinentes (ex : SelectKBest, Recursive Feature Elimination)
# - **Mise à l'échelle des caractéristiques/normalisation**
# - **Rééchantillonnage des données**
#   - Sous-échantillonnage
#   - Sur-échantillonnage

# %% [markdown]
# ## On commence par les bases
#
# - Régression linéaire
# - Régression logistique
# - Analyse discriminante
# - K plus proches voisins
# - **Arbres de décision** : modèles basés sur des règles de décision hiérarchiques pour la classification et la régression (ex : Random Forest)
# - Régression polytomique ordonnée
# - Régression logistique multinomiale
#
#
#
# ### Ressources d'Apprentissage et Lectures Recommandées :
#
# - **Introduction to Statistical Learning** par Gareth James, Daniela Witten, Trevor Hastie, et Robert Tibshirani : [https://www.statlearning.com/](https://www.statlearning.com/)
#
#
# - **The Hundred-Page Machine Learning Book** par Andriy Burkov : [http://themlbook.com/wiki/doku.php](http://themlbook.com/wiki/doku.php)
#
# - **Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow** par Aurélien Géron : [https://powerunit-ju.com/wp-content/uploads/2021/04/Aurelien-Geron-Hands-On-Machine-Learning-with-Scikit-Learn-Keras-and-Tensorflow_-Concepts-Tools-and-Techniques-to-Build-Intelligent-Systems-OReilly-Media-2019.pdf](https://powerunit-ju.com/wp-content/uploads/2021/04/Aurelien-Geron-Hands-On-Machine-Learning-with-Scikit-Learn-Keras-and-Tensorflow_-Concepts-Tools-and-Techniques-to-Build-Intelligent-Systems-OReilly-Media-2019.pdf) |
#
#
# **Projet 10:** Faire un projet complet avec chaque approche

# %%
(# Régression polytomique ordonnées, multinomiales, )

# %% [markdown]
# ## Machine learning avancée
# La machine learning avancée comprend une variété de modèles et d'algorithmes puissants pour la prédiction et l'analyse de données complexes.
#
# Sujets :
# - **Régression pénalisée** Ridge, Lasso, Elastic Net
# - **Forêts aléatoires** : combinaison de plusieurs arbres de décision pour améliorer les performances prédictives (ex : RandomForestClassifier, RandomForestRegressor)
# - **Bagging** : combinaison de plusieurs modèles d'arbres pour améliorer les performances prédictives (ex : BaggingRegressor, BaggingClassifier)
# - **Boosting** : création de modèles successifs pour corriger les erreurs des modèles précédents (ex : Gradient Boosting, AdaBoost, XGBoost, LightGBM)
# - **CatBoost** : algorithme de boosting qui gère automatiquement les variables catégorielles (ex : CatBoostClassifier, CatBoostRegressor)
# - **XGBoost** : framework de boosting optimisé pour la performance et l'efficacité (ex : XGBClassifier, XGBRegressor)
# - **LightGBM** : framework de boosting optimisé pour la vitesse et la mémoire (ex : LGBMClassifier, LGBMRegressor)
#
# Outils :
# - Bibliothèques Python : scikit-learn, CatBoost, XGBoost, LightGBM
# - Bibliothèques R : caret, randomForest
#
# ### Ressources d'Apprentissage et Lectures Recommandées :
#
# - **Introduction to Statistical Learning** par Gareth James, Daniela Witten, Trevor Hastie, et Robert Tibshirani : [https://www.statlearning.com/](https://www.statlearning.com/)
#
#
# - **The Hundred-Page Machine Learning Book** par Andriy Burkov : [http://themlbook.com/wiki/doku.php](http://themlbook.com/wiki/doku.php)
#
# - **Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow** par Aurélien Géron : [https://powerunit-ju.com/wp-content/uploads/2021/04/Aurelien-Geron-Hands-On-Machine-Learning-with-Scikit-Learn-Keras-and-Tensorflow_-Concepts-Tools-and-Techniques-to-Build-Intelligent-Systems-OReilly-Media-2019.pdf](https://powerunit-ju.com/wp-content/uploads/2021/04/Aurelien-Geron-Hands-On-Machine-Learning-with-Scikit-Learn-Keras-and-Tensorflow_-Concepts-Tools-and-Techniques-to-Build-Intelligent-Systems-OReilly-Media-2019.pdf) |

# %% [markdown]
# **Projet 11:** Faire un projet de machine learning avancée

# %% [markdown]
# # Série temporelles
#
# - Introduction aux séries temporelles :
#   - Définition et caractéristiques des séries temporelles
#   - Compréhension des données temporelles
#
# - Analyse exploratoire des séries temporelles :
#   - Visualisation des séries temporelles
#   - Tendances et saisonnalité
#   - Décomposition des séries temporelles en composantes (tendance, saisonnalité, résidus)
#   - Détection des outliers et des valeurs manquantes
#
# - Modélisation des séries temporelles :
#   - Modèles de moyenne mobile (Moving Average, MA)
#   - Modèles autorégressifs (Autoregressive, AR)
#   - Modèles autorégressifs à moyenne mobile (Autoregressive Moving Average, ARMA)
#   - Modèles autorégressifs intégrés à moyenne mobile (Autoregressive Integrated Moving Average, ARIMA)
#   - Modèles saisonniers (Seasonal ARIMA, SARIMA)
#   - Modèles de régression linéaire avec effets temporels
#   - Modèles de séries temporelles avec variables exogènes (VAR, VECM)
#
# - Évaluation des modèles de séries temporelles :
#   - Mesures d'évaluation des prédictions (MSE, MAE, RMSE)
#   - Validation croisée pour les séries temporelles
#   - Comparaison des modèles à l'aide de critères d'information (AIC, BIC)
#
# - Prévision des séries temporelles :
#   - Prévision à court terme et à long terme
#   - Techniques de prévision (Méthode de Holt-Winters, ARIMA, SARIMA)
#   - Évaluation de la précision des prévisions
#
# - Modèles avancés pour les séries temporelles :
#   - Modèles à espace d'état (State Space Models)
#   - Modèles de réseaux de neurones récurrents (RNN) pour les séries temporelles
#   - Modèles de réseaux de neurones récurrents avec mémoire à court terme (LSTM)
#   - Modèles de réseaux de neurones récurrents bidirectionnels (BRNN)

# %% [markdown]
# ## Ressources
#
# - **Introduction aux séries temporelles** :
#     - [Introduction to Time Series Analysis (Duke University)](https://people.duke.edu/~rnau/411home.htm)
#
# - **Analyse exploratoire des séries temporelles** :
#     - [Time Series Analysis and its Applications (Statistics.com)](https://www.statistics.com/time-series-analysis/)
#     - [Time Series Decomposition (Python Data Science Handbook)](https://jakevdp.github.io/PythonDataScienceHandbook/03.11-working-with-time-series.html#Example:-Visualizing-Seattle-Bicycle-Counts)
#
# - **Modélisation des séries temporelles** :
#     - [Forecasting: Principles and Practice (OTexts)](https://otexts.com/fpp2/)
#     - [ARIMA modelling of time series (R-bloggers)](https://www.r-bloggers.com/2015/02/arima-modelling-of-time-series/)
#     - [Time Series Analysis in Python – A Comprehensive Guide with Examples (Machine Learning Plus)](https://www.machinelearningplus.com/time-series/time-series-analysis-python/)
#
# - **Évaluation des modèles de séries temporelles** :
#     - [Time Series Cross Validation (CrossValidated)](https://stats.stackexchange.com/questions/14099/using-k-fold-cross-validation-for-time-series-model-selection)
#
# - **Prévision des séries temporelles** :
#     - [Forecasting: Principles and Practice (OTexts)](https://otexts.com/fpp2/)
#
# - **Modèles avancés pour les séries temporelles** :
#     - [State Space Models (Statsmodels Documentation)](https://www.statsmodels.org/stable/statespace.html)
#     - [Introduction to RNNs, LSTMs and BRNNs (Towards Data Science)](https://towardsdatascience.com/illustrated-guide-to-lstms-and-gru-s-a-step-by-step-explanation-44e9eb85bf21)

# %% [markdown]
# **Projet 12:** Faire des projets en utilisant les séries temporelles

# %% [markdown]
# # Les modèles de durée
#
# - Modèles de survie :
#   - Fonction de survie et fonction de risque
#   - Modèles paramétriques (modèle de survie de Kaplan-Meier, modèle de Cox)
#   - Modèles non paramétriques (estimateurs de Kaplan-Meier)
#   - Censure et troncature des données de durée
#   - Analyse de la proportionnalité des risques
#
# - Modèles de régression de durée :
#   - Modèle de régression linéaire de durée
#   - Modèle de Weibull
#   - Modèle exponentiel
#   - Modèle de log-logistique
#   - Sélection de variables et évaluation des modèles
#
# **Projet 13:** Faire un projet sur le sujet

# %% [markdown]
# ## DEEP LEARNING, NLP, IA GENERATIVE, COMPUTER VISION, REINFORCEMENT LEARNING (Optionel)
#
# ![https://www.researchgate.net/profile/Lily-Popova-Zhuhadar/publication/373797588/figure/fig1/AS:11431281187528395@1694271303862/A-comparative-view-of-AI-machine-learning-deep-learning-and-generative-AI-source.png](https://www.researchgate.net/profile/Lily-Popova-Zhuhadar/publication/373797588/figure/fig1/AS:11431281187528395@1694271303862/A-comparative-view-of-AI-machine-learning-deep-learning-and-generative-AI-source.png)
#
# Si vous souhaitez vous spécialiser vous pouvez approndir les compétences suivantes:
#
# ### Deep Learning
#   - Réseaux de neurones profonds (Deep Neural Networks)
#   - Fonctionnement des couches de neurones (Fully Connected Layers, Convolutional Layers, Recurrent Layers)
#   - Architectures populaires (Convolutional Neural Networks, Recurrent Neural Networks, Generative Adversarial Networks)
#   - Entraînement et rétropropagation (Backpropagation)
#   - Techniques d'optimisation (Gradient Descent, Stochastic Gradient Descent, Adam)
#   - Regularization et techniques d'éviter le surapprentissage (Dropout, L1/L2 Regularization)
#   - Utilisation de bibliothèques populaires (TensorFlow, Keras, PyTorch)
#
# ### NLP (Natural Language Processing)
#   - Prétraitement du texte (Tokenization, Stop Words, Lemmatization, Stemming)
#   - Représentation vectorielle du texte (Word Embeddings, Bag-of-Words, TF-IDF)
#   - Modèles de langage (Language Models)
#   - Tâches de NLP (Classification de texte, Étiquetage morphosyntaxique, Analyse de sentiment, Traduction automatique)
#   - Techniques d'apprentissage (Recurrent Neural Networks, Transformer Models, BERT)
#
#
#  ### IA Generative
#   - Génération de contenu créatif (images, texte, musique)
#   - Modèles génératifs (Generative Adversarial Networks, Variational Autoencoders)
#   - Synthèse de texte (Text-to-Text Generation)
#   - Création d'images et d'art numérique (Image-to-Image Translation, Style Transfer)
#   - Modèles de prédiction de séquences (Sequence-to-Sequence Models)
#   - Techniques de fine-tuning et de transfert d'apprentissage (Transfer Learning, Fine-tuning)
#
#
# ### Computer Vision
#   - Prétraitement des images (Redimensionnement, Normalisation, Augmentation de données)
#   - Réseaux de neurones pour la vision par ordinateur (Convolutional Neural Networks)
#   - Détection d'objets (Object Detection)
#   - Segmentation d'images (Image Segmentation)
#   - Reconnaissance faciale (Facial Recognition)
#   - Utilisation de bibliothèques populaires (OpenCV, TensorFlow, PyTorch)
#
# ### Reinforcement Learning
#   - Apprentissage par renforcement (Reinforcement Learning)
#   - Agents et environnements (Agents, Environments)
#   - Processus de décision markovien (Markov Decision Process)
#   - Méthodes de contrôle (Value Iteration, Policy Iteration, Q-Learning)
#   - Exploration et exploitation (Exploration vs Exploitation)
#   - Applications et cas d'utilisation (Jeux, Robotique, Finance)

# %% [markdown]
# ### Les ressources
#
#
# #### Deep Learning
# - [Deep Learning Book par Ian Goodfellow, Yoshua Bengio et Aaron Courville](http://www.deeplearningbook.org/)
# - [Deep Learning Specialization par Andrew Ng sur Coursera](https://www.coursera.org/specializations/deep-learning)
# - [TensorFlow Tutoriels](https://www.tensorflow.org/tutorials)
# - [PyTorch Tutoriels](https://pytorch.org/tutorials/)
#
# #### NLP (Natural Language Processing)
# - [Natural Language Processing with Python](https://www.nltk.org/book/)
# - [Stanford's NLP Course CS224n](http://web.stanford.edu/class/cs224n/)
# - [Hugging Face's Transformers](https://huggingface.co/transformers/)
#
# #### Computer Vision
# - [Stanford's Convolutional Neural Networks for Visual Recognition (CS231n)](http://cs231n.stanford.edu/)
# - [OpenCV Tutoriels](https://docs.opencv.org/master/d9/df8/tutorial_root.html)
# - [Fast.ai's Practical Deep Learning for Coders](https://www.fast.ai/)
#
# #### Reinforcement Learning
# - [Reinforcement Learning: An Introduction par Richard S. Sutton et Andrew G. Barto](http://incompleteideas.net/book/the-book-2nd.html)
# - [Deep Reinforcement Learning Course](https://deepmind.com/learning-resources/-introduction-reinforcement-learning-david-silver)

# %% [markdown]
# **Projet 14:** faire des projets pour chaque thématique

# %% [markdown]
# # Pour devenir un Full Stack Data Scientist

# %% [markdown]
# **Partie 1 :** Bonnes pratiques de développement (Programme ENSAE)
# - Ingénierie logicielle Améliorez votre capacité à écrire du code propre, lisible et réutilisable. Approfondissez votre connaissance de plusieurs langages de programmation, des structures de données, des algorithmes et des principes de l'ingénierie logicielle.
# - Architectures de projet
# - Travail collaboratif avec Git et GitHub
#
# **Partie 2 :** Vers la mise en production
# - Maximiser la reproductibilité et la portabilité des projets
# - Environnements virtuels : venv et conda
# - Conteneurisation : Docker
# - Déployer et valoriser un projet de data science
# - Environnements de production
# - **DevOps** Intégration continue (CI) et déploiement en continu (CD)
# - Principes de Kubernetes (orchestration)
# - Formats de valorisation
# - Introduction au MLOps
# - **Développement d'APIs**
# Les APIs permettent à d'autres systèmes et services d'interagir avec vos modèles déployés. Acquérez des connaissances sur le développement d'APIs, notamment avec des frameworks comme Flask ou FastAPI.
# - **Cloud Computing**
# Une connaissance des services de cloud computing, tels que AWS, Google Cloud, ou Microsoft Azure, peut être utile pour le stockage et le traitement de grandes quantités de données, ainsi que pour le déploiement de modèles à grande échelle.
#
# Autres compétences
# - **Gestion de bases de données**
# La capacité de travailler avec des bases de données, y compris les bases de données relationnelles (SQL) et non relationnelles (NoSQL), est souvent une compétence importante.
#
# - **Conception et mise en œuvre d'architectures de données**
# Apprenez à concevoir et à mettre en œuvre des architectures de données qui répondent aux besoins de l'entreprise et qui sont évolutives et maintenables.
#
# - **Environnements de Big Data**
# Acquérir une compréhension des environnements de big data et des outils couramment utilisés pour gérer de grands volumes de données. Cela pourrait inclure des technologies comme Hadoop, Spark et Kafka.

# %% [markdown]
# Ressources:
#
# 1. Lien utile : [https://ensae-reproductibilite.github.io/website/](https://ensae-reproductibilite.github.io/website/)
#
#
# 1. **GIT** : [Pro Git Book](https://git-scm.com/book/en/v2) - Un livre gratuit qui couvre tous les aspects de Git.
# 2. **Gestion des bases de données** :
#    * SQL - [SQL for Data Analysis](https://www.udacity.com/course/sql-for-data-analysis--ud198) par Udacity
#    * NoSQL - [Introduction to NoSQL Data Solutions](https://www.edx.org/professional-certificate/introduction-to-nosql-data-solutions) sur edX
# 3. **Conception et mise en œuvre d'architectures de données** : [Data Warehousing for Business Intelligence](https://www.coursera.org/specializations/data-warehousing) spécialisation sur Coursera
# 4. **ETL (Extract, Transform, Load)** : [Data Warehousing and ETL](https://www.udemy.com/course/data-warehousing-and-etl/) sur Udemy
# 5. **Cloud Computing** :
#    * [AWS Training and Certification](https://aws.amazon.com/training/)
#    * [Google Cloud Training](https://cloud.google.com/training)
#    * [Azure Training and Certification](https://docs.microsoft.com/en-us/learn/azure/)
# 6. **Big Data** : [Big Data University](https://cognitiveclass.ai/courses/what-is-big-data/) sur Cognitive Class par IBM
# 7. **Docker et Kubernetes** : [Learn Docker & Kubernetes](https://www.udemy.com/course/docker-and-kubernetes-the-complete-guide/) sur Udemy
# 8. **Développement d'APIs** : [Designing RESTful APIs](https://www.udacity.com/course/designing-restful-apis--ud388) par Udacity
# 9. **CI/CD** : [Learn DevOps: The Complete Kubernetes Course](https://www.udemy.com/course/learn-devops-the-complete-kubernetes-course/) sur Udemy
# 10. **DevOps** : [DevOps Culture and Mindset](https://www.coursera.org/learn/devops-culture-and-mindset) sur Coursera
