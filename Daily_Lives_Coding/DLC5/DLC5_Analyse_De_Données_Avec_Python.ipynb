# %% [markdown]
# ![programme](DLC5.png)

# %% [markdown]
# # Projet Analyse des Données Bancaires

# %% [markdown]
# ## Contexte
#
# Vous êtes data scientist/data analyst dans une banque et votre entreprise souhaite **analyser l'efficacité des campagnes de marketing direct basées sur les appels téléphoniques**.
#
# L'objectif est de **déterminer si ces campagnes influencent positivement la souscription des clients à des dépôts à terme**.
#
# Pour cela, vous disposez de quatre ensembles de données détaillant les interactions avec les clients sur une période allant de **mai 2008 à novembre 2010**.
#
#
#
# ## Objectif
#
# Votre mission consiste à effectuer une analyse exploratoire des données pour identifier les tendances, les comportements des clients, et d'autres insights pertinents qui peuvent aider la banque à optimiser ses futures campagnes de marketing.
#
#
#
# ## Jeu De données
#
# ## Jeu de Données
#
# Vous disposez du jeu de données `donnee_marketing_banque.csv`, qui comprend **41 188 exemples avec 20 variables**, couvrant la période de mai 2008 à novembre 2010. Ces données incluent des informations sur les appels effectués, les caractéristiques des clients, et la réponse finale du client (souscription ou non à un dépôt à terme).
#
# Le jeu de données peut être téléchargé à partir du [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Bank+Marketing).

# %% [markdown]
# # Description des données

# %% [markdown]
# ## Description des Variables
#
# - `age`: Âge du client.
# - `job`: Type de métier du client (ex. "manager", "blue-collar", "retired").
# - `marital`: État civil du client (ex. "married", "single", "divorced").
# - `education`: Niveau d'études du client (ex. "secondary", "primary", "tertiary").
# - `default`: Présence ou absence de défaut de paiement de crédit (ex. "yes", "no").
# - `balance`: Solde annuel moyen sur le compte du client.
# - `housing`: Présence ou absence de prêt immobilier (ex. "yes", "no").
# - `loan`: Présence ou absence de prêt personnel (ex. "yes", "no").
# - `contact`: Moyen de communication avec le client (ex. "telephone", "cellular", "unknown").
# - `day`: Jour du mois de la dernière prise de contact.
# - `month`: Mois de l'année de la dernière prise de contact.
# - `duration`: Durée de la dernière communication, en secondes.
# - `campaign`: Nombre de contacts effectués pendant cette campagne pour ce client.
# - `pdays`: Nombre de jours écoulés depuis le dernier contact du client lors d'une campagne précédente (999 indique que le client n'a pas été contacté précédemment).
# - `previous`: Nombre de contacts réalisés avant cette campagne pour ce client.
# - `poutcome`: Résultat de la campagne marketing précédente (ex. "failure", "nonexistent", "success").
# - `y`: Le client a-t-il souscrit un dépôt à terme ? (variable cible, ex. "yes", "no").

# %% [markdown]
# # Installation et chargement de pandas

# %%
# Installation si nécessaire
# !pip install pandas
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
# Chargement de la librairie pandas
import pandas as pd

# %% [markdown]
# # Importer les données

# %% [markdown]
# ## Importer un fichier csv

# %% [markdown]
# Documentation de pd.read_csv: [https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)

# %%
# importation de la base sans prise en compte des séparateurs
df = pd.read_csv("donnees_marketing_banque.csv")
df
# Out:
#       id;age;job;marital;education;default;balance;housing;loan;contact;day;month;duration;campaign;pdays;previous;poutcome;y
# 0      id1;58;management;married;tertiary;no;2143;yes...
# 1      id2;44;technician;single;secondary;no;29;yes;n...
# 2      id3;33;entrepreneur;married;secondary;no;2;yes...
# 3      id4;47;blue-collar;married;unknown;no;1506;yes...
# 4      id5;33;unknown;single;unknown;no;1;no;no;unkno...
# ...                                                  ...
# 45206  id45207;51;technician;married;tertiary;no;825;...
# 45207  id45208;71;retired;divorced;primary;no;1729;no...
# 45208  id45209;72;retired;married;secondary;no;5715;n...
# 45209  id45210;57;blue-collar;married;secondary;no;66...
# 45210  id45211;37;entrepreneur;married;secondary;no;2...
#
# [45211 rows x 1 columns]

# %%
df = pd.read_csv("donnees_marketing_banque.csv", sep = ";")
df
# Out:
#             id  age           job   marital  education default  balance  \
# 0          id1   58    management   married   tertiary      no   2143.0
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 3          id4   47   blue-collar   married    unknown      no   1506.0
# 4          id5   33       unknown    single    unknown      no      1.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %% [markdown]
# ## Importer un fichier excel

# %%
# Importer le fichier excel
df = pd.read_excel("donnees_marketing_banque.xlsx")
df
# Out:
#             id  age           job   marital  education default  balance  \
# 0          id1   58    management   married   tertiary      no   2143.0
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 3          id4   47   blue-collar   married    unknown      no   1506.0
# 4          id5   33       unknown    single    unknown      no      1.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Quels sont les  premiers/ derniers clients de la base de données?

# %% [markdown]
# ![https://storage.googleapis.com/lds-media/images/series-and-dataframe.width-1200.png](https://storage.googleapis.com/lds-media/images/series-and-dataframe.width-1200.png)

# %%
# Maitrise de la fonction head 
df.head()
# Out:
#     id  age           job  marital  education default  balance housing loan  \
# 0  id1   58    management  married   tertiary      no   2143.0     yes   no
# 1  id2   44    technician   single  secondary      no     29.0     yes   no
# 2  id3   33  entrepreneur  married  secondary      no      2.0     yes  yes
# 3  id4   47   blue-collar  married    unknown      no   1506.0     yes   no
# 4  id5   33       unknown   single    unknown      no      1.0      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
# Les 10 premiers
df.head(100)
# Out:
#        id  age           job  marital  education default  balance housing  \
# 0     id1   58    management  married   tertiary      no   2143.0     yes
# 1     id2   44    technician   single  secondary      no     29.0     yes
# 2     id3   33  entrepreneur  married  secondary      no      2.0     yes
# 3     id4   47   blue-collar  married    unknown      no   1506.0     yes
# 4     id5   33       unknown   single    unknown      no      1.0      no
# ..    ...  ...           ...      ...        ...     ...      ...     ...
# 95   id96   36    management  married   tertiary      no    101.0     yes
# 96   id97   55   blue-collar  married  secondary      no    383.0      no
# 97   id98   60       retired  married   tertiary      no     81.0     yes
# 98   id99   39    technician  married  secondary      no      0.0     yes
# 99  id100   46    management  married   tertiary      no    229.0     yes
#
#    loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
# Les dernières lignes de la base de données 
df.tail()
# Out:
#             id  age           job   marital  education default  balance  \
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 45206      no   no   cellular   17   nov       977         3     -1         0
# 45207      no   no   cellular   17   nov       456         2     -1         0
# 45208      no   no   cellular   17   nov      1127         5    184         3
# 45209      no   no  telephone   17   nov       508         4     -1         0
# 45210      no   no   cellular   17   nov       361         2    188        11
#
#       poutcome    y
# 45206  unknown  yes
# 45207  unknown  yes
# ...

# %%
# Les 10 dernières lignes
df.tail(10)
# Out:
#             id  age           job   marital  education default  balance  \
# 45201  id45202   53    management   married   tertiary      no    583.0
# 45202  id45203   34        admin.    single  secondary      no    557.0
# 45203  id45204   23       student    single   tertiary      no    113.0
# 45204  id45205   73       retired   married  secondary      no   2850.0
# 45205  id45206   25    technician    single  secondary      no    505.0
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 45201      no   no   cellular   17   nov       226         1    184         4
# ...

# %% [markdown]
# ## Quels sont les variables de l'analyse ?

# %%
# Listes des colonnes
df.columns
# Out:
# Index(['id', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
# Nature des données de la base dtypes
df.dtypes
# Out:
# id            object
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance      float64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# y             object
# dtype: object

# %% [markdown]
# ## Combien de clients et combien de variables?

# %%
# Dimension du tableau (shape)
df.shape
# Out:
# (45211, 18)

# %% [markdown]
# ## Description rapide de la base

# %%
# Utilisation de describe
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45206.000000  45211.000000  45211.000000  45211.000000
# mean      40.931477    1362.403707     15.806419    258.163080      2.763841
# std       10.623372    3044.906741      8.322476    257.527812      3.098021
# min       10.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
# include =. "all"
df.describe(include = "all")
# Out:
#            id           age          job  marital  education default  \
# count   45211  45211.000000        45211    45211      45211   45211
# unique  45211           NaN           12        3          4       2
# top       id1           NaN  blue-collar  married  secondary      no
# freq        1           NaN         9732    27214      23202   44396
# mean      NaN     40.931477          NaN      NaN        NaN     NaN
# std       NaN     10.623372          NaN      NaN        NaN     NaN
# min       NaN     10.000000          NaN      NaN        NaN     NaN
# 25%       NaN     33.000000          NaN      NaN        NaN     NaN
# 50%       NaN     39.000000          NaN      NaN        NaN     NaN
# 75%       NaN     48.000000          NaN      NaN        NaN     NaN
# max       NaN     95.000000          NaN      NaN        NaN     NaN
#
#               balance housing   loan   contact           day  month  \
# count    45206.000000   45211  45211     45211  45211.000000  45211
# ...

# %%
# Modalité de la variable éducation
df['education'].unique()
# Out:
# array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object)

# %%
# Nombre de valeur par modalité

df['education'].value_counts()
# Out:
# education
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: count, dtype: int64

# %%
df['education'].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='education'>

# %% [markdown]
# # Nétoyage des données

# %%
# Trouver le nombre de valeur manquante par variable

# %%
# description include = "all"

# %% [markdown]
# ## Valeurs manquantes

# %%
# Mettre l'id en index pour qu'il ne soit plus considéré comme une variable inplace = true
df.isnull().sum()
# Out:
# id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      5
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
# Somme des valeurs manquantes isna 

df.isna().sum()
# Out:
# id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      5
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
# Somme des valeurs manquantes isna

# %%
## Traitement valeurs manquantes: solution 1 suprimer  axis : {0 or 'index', 1 or 'columns'}, default 0

# Supprimer les lignes manquantes
df_delete_missing = df.dropna(axis = 0)
df_delete_missing.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45206.000000   45206.000000  45206.000000  45206.000000  45206.000000
# mean      40.930828    1362.403707     15.807614    258.161616      2.764036
# std       10.623495    3044.906741      8.322160    257.539139      3.098137
# min       10.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45206.000000  45206.000000
# mean      40.202385      0.580388
# std      100.133346      2.303560
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
# Supprimer les lignes manquantes
df_delete_column = df.dropna(axis = 1)
df_delete_column.describe()
# Out:
#                 age           day      duration      campaign         pdays  \
# count  45211.000000  45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.931477     15.806419    258.163080      2.763841     40.197828
# std       10.623372      8.322476    257.527812      3.098021    100.128746
# min       10.000000      1.000000      0.000000      1.000000     -1.000000
# 25%       33.000000      8.000000    103.000000      1.000000     -1.000000
# 50%       39.000000     16.000000    180.000000      2.000000     -1.000000
# 75%       48.000000     21.000000    319.000000      3.000000     -1.000000
# max       95.000000     31.000000   4918.000000     63.000000    871.000000
#
#            previous
# count  45211.000000
# mean       0.580323
# std        2.303441
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      275.000000

# %%
## Solution 3 remplacer les valeurs manquantes par une valeur spécique
df_remplacer = df.fillna(0)
df_remplacer.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.931477    1362.253036     15.806419    258.163080      2.763841
# std       10.623372    3044.772068      8.322476    257.527812      3.098021
# min       10.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
## Solution 4 remplacer par la moyenne
moyenne = df["balance"].mean()
moyenne
#Sélection d'une colonne
df_remplacer = df.fillna(moyenne)
df_remplacer.describe()
print("somme des valeurs manquantes ", df_remplacer.isnull().sum()) # somme 
print("somme des valeurs manquantes ", df_remplacer.isnull().mean()) # proportion
# Out:
# somme des valeurs manquantes  id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64
# somme des valeurs manquantes  id           0.0
# age          0.0
# job          0.0
# marital      0.0
# education    0.0
# default      0.0
# balance      0.0
# housing      0.0
# loan         0.0
# contact      0.0
# day          0.0
# month        0.0
# duration     0.0
# campaign     0.0
# pdays        0.0
# previous     0.0
# poutcome     0.0
# y            0.0
# dtype: float64

# %% [markdown]
# # Quiz
#
# # Question 1
# Comment remplaceriez-vous les valeurs manquantes d'une colonne spécifique par la médiane dans cette colonne en utilisant Pandas ?
#
# A) df['colonne'].fillna(df['colonne'].median(), inplace=True)
#
# B) df['colonne'].replace(np.nan, df['colonne'].median(), inplace=True)
#
# C) df['colonne'] = df['colonne'].fillna(df['colonne'].median())

# %% [markdown]
# # Question 2
#
# Comment afficher les 30 premières lignes d'un DataFrame Pandas ?
#
# A) df.head(30)
#
# B) df.iloc[0:30]
#
# C) df[:30]

# %% [markdown]
# ## Suppression des colonnes inutiles

# %%
# Suppression d'une seule colonne (month et day) (drop([]) axis)
df_without_month = df.drop(["month"], axis = 1)
df_without_month
# Out:
#             id  age           job   marital  education default  balance  \
# 0          id1   58    management   married   tertiary      no   2143.0
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 3          id4   47   blue-collar   married    unknown      no   1506.0
# 4          id5   33       unknown    single    unknown      no      1.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day  duration  campaign  pdays  previous  \
# ...

# %%
df_without_month_day = df.drop(["month", "day", "age"], axis = 1)
df_without_month_day
# Out:
#             id           job   marital  education default  balance housing  \
# 0          id1    management   married   tertiary      no   2143.0     yes
# 1          id2    technician    single  secondary      no     29.0     yes
# 2          id3  entrepreneur   married  secondary      no      2.0     yes
# 3          id4   blue-collar   married    unknown      no   1506.0     yes
# 4          id5       unknown    single    unknown      no      1.0      no
# ...        ...           ...       ...        ...     ...      ...     ...
# 45206  id45207    technician   married   tertiary      no    825.0      no
# 45207  id45208       retired  divorced    primary      no   1729.0      no
# 45208  id45209       retired   married  secondary      no   5715.0      no
# 45209  id45210   blue-collar   married  secondary      no    668.0      no
# 45210  id45211  entrepreneur   married  secondary      no   2971.0      no
#
# ...

# %% [markdown]
# ## Choisir une ou des  colonnes spécifiques (age et loan, education, default)

# %%
# Choisir et décrire une variable à partir du nom première approche
age = df["age"]
print(age)
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45206    51
# 45207    71
# 45208    72
# 45209    57
# 45210    37
# Name: age, Length: 45211, dtype: int64

# %%
# type de la colonne 
type(age)
# Out:
# pandas.core.series.Series

# %%
# stat sur la colonne
age.describe()
# Out:
# count    45211.000000
# mean        40.931477
# std         10.623372
# min         10.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %%
# Deuxième approche pour choisir une colonne
age = df.age
print(age)
type(age)
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45206    51
# 45207    71
# 45208    72
# 45209    57
# 45210    37
# Name: age, Length: 45211, dtype: int64
# pandas.core.series.Series

# %%
# Choisir et décrire plusieurs variables à partir des nom
base_select = df[["age", "loan", "education"]]
base_select
# Out:
#        age loan  education
# 0       58   no   tertiary
# 1       44   no  secondary
# 2       33  yes  secondary
# 3       47   no    unknown
# 4       33   no    unknown
# ...    ...  ...        ...
# 45206   51   no   tertiary
# 45207   71   no    primary
# 45208   72   no  secondary
# 45209   57   no  secondary
# 45210   37   no  secondary
#
# [45211 rows x 3 columns]

# %%
liste_variable = ["age", "loan", "education"]
base_select = df[liste_variable]
print(base_select)
type(base_select)
# Out:
#        age loan  education
# 0       58   no   tertiary
# 1       44   no  secondary
# 2       33  yes  secondary
# 3       47   no    unknown
# 4       33   no    unknown
# ...    ...  ...        ...
# 45206   51   no   tertiary
# 45207   71   no    primary
# 45208   72   no  secondary
# 45209   57   no  secondary
# 45210   37   no  secondary
#
# [45211 rows x 3 columns]
# pandas.core.frame.DataFrame

# %%
# Sélection avec .loc et récupération de toutes les lignes

base_select = df.loc[:,liste_variable]
base_select
# Out:
#        age loan  education
# 0       58   no   tertiary
# 1       44   no  secondary
# 2       33  yes  secondary
# 3       47   no    unknown
# 4       33   no    unknown
# ...    ...  ...        ...
# 45206   51   no   tertiary
# 45207   71   no    primary
# 45208   72   no  secondary
# 45209   57   no  secondary
# 45210   37   no  secondary
#
# [45211 rows x 3 columns]

# %%
# Sélection des 10 première lignes
base_select = df.loc[0:10,liste_variable]
base_select
# Out:
#     age loan  education
# 0    58   no   tertiary
# 1    44   no  secondary
# 2    33  yes  secondary
# 3    47   no    unknown
# 4    33   no    unknown
# 5    35   no   tertiary
# 6    28  yes   tertiary
# 7    42   no   tertiary
# 8    58   no    primary
# 9    43   no  secondary
# 10   41   no  secondary

# %%
# Choisir à partir des numéros de la colonnes iloc[]
base_wiht_iloc = df.iloc[:, 1]
base_wiht_iloc
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45206    51
# 45207    71
# 45208    72
# 45209    57
# 45210    37
# Name: age, Length: 45211, dtype: int64

# %%
# Choisir plusieurs colonnes à partir du numéro
base_wiht_iloc = df.iloc[:, [1,3,5]]
base_wiht_iloc
# Out:
#        age   marital default
# 0       58   married      no
# 1       44    single      no
# 2       33   married      no
# 3       47   married      no
# 4       33    single      no
# ...    ...       ...     ...
# 45206   51   married      no
# 45207   71  divorced      no
# 45208   72   married      no
# 45209   57   married      no
# 45210   37   married      no
#
# [45211 rows x 3 columns]

# %%
# Choisir plusieurs colonnes à partir du numéro (100 première lignes)
base_wiht_iloc = df.iloc[0:100, [1,3,5]]
base_wiht_iloc
# Out:
#     age  marital default
# 0    58  married      no
# 1    44   single      no
# 2    33  married      no
# 3    47  married      no
# 4    33   single      no
# ..  ...      ...     ...
# 95   36  married      no
# 96   55  married      no
# 97   60  married      no
# 98   39  married      no
# 99   46  married      no
#
# [100 rows x 3 columns]

# %%
# Choisir plusieurs colonnes à partir du numéro (100 première lignes)
base_wiht_iloc = df.iloc[:100, [1,3,5]]
base_wiht_iloc
# Out:
#     age  marital default
# 0    58  married      no
# 1    44   single      no
# 2    33  married      no
# 3    47  married      no
# 4    33   single      no
# ..  ...      ...     ...
# 95   36  married      no
# 96   55  married      no
# 97   60  married      no
# 98   39  married      no
# 99   46  married      no
#
# [100 rows x 3 columns]

# %%
# Choisir plusieurs colonnes à partir du numéro (100 première lignes)
base_wiht_iloc = df.iloc[4:, [1,3,5]]
base_wiht_iloc
# Out:
#        age   marital default
# 4       33    single      no
# 5       35   married      no
# 6       28    single      no
# 7       42  divorced     yes
# 8       58   married      no
# ...    ...       ...     ...
# 45206   51   married      no
# 45207   71  divorced      no
# 45208   72   married      no
# 45209   57   married      no
# 45210   37   married      no
#
# [45207 rows x 3 columns]

# %%
base_wiht_iloc.describe()
# Out:
#                 age
# count  45207.000000
# mean      40.931073
# std       10.623426
# min       10.000000
# 25%       33.000000
# 50%       39.000000
# 75%       48.000000
# max       95.000000

# %% [markdown]
# # Quiz
#
#
#
# Quelle est la principale différence entre iloc et loc en Pandas ?
#
# A) `iloc` est basé sur l'indexation par étiquettes, tandis que `loc` est basé sur l'indexation par position.
#
# B) `iloc` est basé sur l'indexation par position, tandis que `loc` est basé sur l'indexation par étiquettes.
#
# C) `iloc` et `loc` ne diffèrent pas et peuvent être utilisés de manière interchangeable.

# %% [markdown]
# ## Sélectionner un périmètre d'analyse

# %%
# Première approche
df["age"] >= 18
base_majeur = df[df["age"] >= 18]
base_majeur
# Out:
#             id  age           job   marital  education default  balance  \
# 0          id1   58    management   married   tertiary      no   2143.0
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 3          id4   47   blue-collar   married    unknown      no   1506.0
# 4          id5   33       unknown    single    unknown      no      1.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
# Première approche

base_majeur = df[(df["age"] >= 18) & (df["education"] == "secondary")]
base_majeur
# Out:
#             id  age           job   marital  education default  balance  \
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 9         id10   43    technician    single  secondary      no      NaN
# 10        id11   41        admin.  divorced  secondary      no    270.0
# 11        id12   29        admin.    single  secondary      no    390.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45204  id45205   73       retired   married  secondary      no   2850.0
# 45205  id45206   25    technician    single  secondary      no    505.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
base_majeur.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  23199.000000  23197.000000  23199.000000  23199.000000  23199.000000
# mean      39.964352   1155.090184     15.760550    258.699556      2.701022
# std       10.159050   2558.490233      8.306735    253.324101      2.985916
# min       18.000000  -8019.000000      1.000000      0.000000      1.000000
# 25%       32.000000     55.000000      8.000000    105.000000      1.000000
# 50%       38.000000    392.000000     16.000000    183.000000      2.000000
# 75%       47.000000   1234.000000     21.000000    321.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     55.000000
#
#               pdays      previous
# count  23199.000000  23199.000000
# mean      42.359110      0.567826
# std      103.595216      1.849975
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# ...

# %%
base_majeur["education"].unique()
# Out:
# array(['secondary'], dtype=object)

# %%
base_majeur.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45203.000000   45198.000000  45203.000000  45203.000000  45203.000000
# mean      40.936133    1362.631997     15.808331    258.168816      2.764153
# std       10.618494    3045.126997      8.321971    257.548471      3.098206
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     449.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45203.000000  45203.000000
# mean      40.205119      0.580426
# std      100.136106      2.303632
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
# Description
base_majeur = df.loc[df["age"] >= 18]
base_majeur
# Out:
#             id  age           job   marital  education default  balance  \
# 0          id1   58    management   married   tertiary      no   2143.0
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 3          id4   47   blue-collar   married    unknown      no   1506.0
# 4          id5   33       unknown    single    unknown      no      1.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
# Travailler uniquement sur les clients majeurs (loc première approche)

# %%
# Filtre sur les majeurs et conserver uniqument l'age, education et le solde du compte (.loc)
# Possibilité de mettre plusieurs conditions

base_majeur = df[(df["age"] >= 18) & (df["education"] == "secondary")][["education","age","marital"]]
base_majeur
# Out:
#        education  age   marital
# 1      secondary   44    single
# 2      secondary   33   married
# 9      secondary   43    single
# 10     secondary   41  divorced
# 11     secondary   29    single
# ...          ...  ...       ...
# 45204  secondary   73   married
# 45205  secondary   25    single
# 45208  secondary   72   married
# 45209  secondary   57   married
# 45210  secondary   37   married
#
# [23199 rows x 3 columns]

# %%
base_select = df.loc[df["age"] >= 18, ["age", "education", "marital"]]
base_select
# Out:
#        age  education   marital
# 0       58   tertiary   married
# 1       44  secondary    single
# 2       33  secondary   married
# 3       47    unknown   married
# 4       33    unknown    single
# ...    ...        ...       ...
# 45206   51   tertiary   married
# 45207   71    primary  divorced
# 45208   72  secondary   married
# 45209   57  secondary   married
# 45210   37  secondary   married
#
# [45203 rows x 3 columns]

# %%
base_select.describe(include = "all")
# Out:
#                  age  education  marital
# count   45203.000000      45203    45203
# unique           NaN          4        3
# top              NaN  secondary  married
# freq             NaN      23199    27211
# mean       40.936133        NaN      NaN
# std        10.618494        NaN      NaN
# min        18.000000        NaN      NaN
# 25%        33.000000        NaN      NaN
# 50%        39.000000        NaN      NaN
# 75%        48.000000        NaN      NaN
# max        95.000000        NaN      NaN

# %%
# Sélectionner les 10 première lignes

# %%
base_select = df.loc[5:10, ["age", "education", "marital"]]
base_select
# Out:
#     age  education   marital
# 5    35   tertiary   married
# 6    28   tertiary    single
# 7    42   tertiary  divorced
# 8    58    primary   married
# 9    43  secondary    single
# 10   41  secondary  divorced

# %%
base_select = df.iloc[5:10, 5:10]
base_select
# Out:
#   default  balance housing loan  contact
# 5      no    231.0     yes   no  unknown
# 6      no    447.0     yes  yes  unknown
# 7     yes      2.0     yes   no  unknown
# 8      no    121.0     yes   no  unknown
# 9      no      NaN     yes   no  unknown

# %% [markdown]
# # Créer une colonne tranche d'age <18 entre 18 et 25 , de 25 à 50 et plus de 50

# %%
#np.nan
import numpy as np
df["tranche_age"] = np.nan
df.columns
# Out:
# Index(['id', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'y', 'tranche_age'],
#       dtype='object')

# %%
df["tranche_age"][df["age"] < 18] = "<18"
df["tranche_age"][(df["age"] >= 18) & (df["age"] < 25)] = "18-25"
df["tranche_age"][(df["age"] >= 25) & (df["age"] < 50)] = "25-50"
df["tranche_age"][(df["age"] >= 50)] = ">=50"

# %%
df["tranche_age"].unique()
# Out:
# array(['>=50', '25-50', '<18', '18-25'], dtype=object)

# %%
df.dtypes
# Out:
# id              object
# age              int64
# job             object
# marital         object
# education       object
# default         object
# balance        float64
# housing         object
# loan            object
# contact         object
# day              int64
# month           object
# duration         int64
# campaign         int64
# pdays            int64
# previous         int64
# poutcome        object
# y               object
# tranche_age     object
# dtype: object

# %%
df["tranche_age"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='tranche_age'>

# %%
# Faire l'histogramme de la variable balance 
df["balance"].hist()
# Out:
# <Axes: >

# %%
# Analyser le solde moyen par tranche d'âge (groupby .mean())
df.groupby("tranche_age")["balance"].mean()
# Out:
# tranche_age
# 18-25     916.949257
# 25-50    1236.063830
# <18        72.625000
# >=50     1822.763788
# Name: balance, dtype: float64

# %% [markdown]
# # Exercice:
#
# Donner le code qui fait un filtre sur les clients de plus de 25 ans et calcul l'age moyen en fonction du niveau d'éducation

# %%
df[df["age"] > 25].groupby("education")["age"].mean()
# Out:
# education
# primary      46.197571
# secondary    40.616153
# tertiary     39.883466
# unknown      45.830576
# Name: age, dtype: float64

# %%
df_sup25 =df[df["age"] > 25]

df_sup25.groupby("education")["age"].mean()
# Out:
# education
# primary      46.197571
# secondary    40.616153
# tertiary     39.883466
# unknown      45.830576
# Name: age, dtype: float64

# %% [markdown]
# ## Exercices de Manipulation de Données avec Pandas
#
# ### Contexte
# Vous êtes data scientist/data analyst dans une banque, et vous avez pour mission d'analyser l'efficacité des campagnes de marketing direct basées sur les appels téléphoniques, dans le but de déterminer leur influence sur la souscription des clients à des dépôts à terme.
#
# ### Exercice 1: Analyse descriptive des caractéristiques des clients
# **Objectif:** Explorer les caractéristiques de base des clients et leur réponse aux campagnes de marketing.
#
# **Tâches:**
# 1. Charger le jeu de données `donnee_marketing_banque.csv` dans un DataFrame Pandas.
# 2. Sélectionner les colonnes pertinentes telles que l'âge, le métier, le statut matrimonial, et l'éducation.
# 3. Utiliser `describe()` pour obtenir un résumé statistique de ces variables.
# 4. Créer des groupes basés sur le statut de souscription et comparer la variable balance pour ces groupes
#
# ---
#
#
#
#
# ### Exercice 3: Analyse des résultats des appels par catégorie professionnelle
# **Objectif:** Examiner l'efficacité des appels selon la profession des clients.
#
# **Tâches:**
# 1. Charger le jeu de données dans un DataFrame.
# 2. Sélectionner les colonnes de profession et de résultat de l'appel.
# 3. Utiliser `groupby()` pour regrouper les données par profession.
# 4. Calculer le nombre total d'appels et le taux de succès par profession.
# 5. Analyser les professions avec les taux de succès les plus élevés et les plus bas.
#
# ---
#
# ### Exercice 4: Filtrage des clients selon des critères spécifiques
# **Objectif:** Filtrer les données pour analyser des segments spécifiques de clients.
#
# **Tâches:**
# 1. Charger le jeu de données dans un DataFrame.
# 2. Sélectionner des critères de filtrage numérique et non numérique (âge, profession, éducation, etc.).
# 3. Appliquer un filtre pour sélectionner les clients répondant à ces critères.
# 4. Utiliser `describe()` pour analyser les caractéristiques de ce segment.
#
#
# ---
